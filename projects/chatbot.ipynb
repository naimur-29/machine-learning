# %%
pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 211 kB 29.7 MB/s
# ...
#      |████████████████████████████████| 7.4 MB 65.3 MB/s
# ...
#      |████████████████████████████████| 81 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.1 MB/s
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13553 sha256=dc9dfe003d94107f790b6806c4895e2ba56d290a829a377ce0d4300d96f1221c
#   Stored in directory: /root/.cache/pip/wheels/df/67/41/faca10fa501ca010be41b49d40360c2959e1c4f09bcbfa37fa
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3357 sha256=d31518fbb24bc8f1aa7aa7378bf846edb14911cf9a2f18a59dd861ccd95c51d3
#   Stored in directory: /root/.cache/pip/wheels/7f/d4/8f/6e2ca54744c9d7292d88ddb8d42876bcdab5e6d84a21c10346
# ...

# %%
from newspaper import Article
import random
import string
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
nltk.download('punkt', quiet=True)
# Out:
# True

# %%
#Get the article
article = Article('https://www.thedailystar.net/shout/news/mushoku-tensei-the-new-benchmark-isekai-anime-3087046')
article.download()
article.parse()
article.nlp()
corpus = article.text

# %%
print(corpus)
# Out:
# Isekai is currently one of the most popular genres in anime which blew up after the massive success of Sword Art Online in 2012. Despite not being the first of its kind, the popularity of SAO has spawned numerous isekai anime over the years, some with a similar setting having unique quirks while others being blatant clones of the previous.
#
# With 21 isekai anime being released in 2021 alone, the genre definitely feels monotonous and overdone. Mushoku Tensei, being one of them, may seem to be conceptually identical, but it could not be more different in terms of quality and execution.
#
# Adapted from Rifujin na Magonote's light novel, Mushoku Tensei builds on the concept of reincarnation in an alternate fantasy world, where the jobless and hopeless protagonist is reborn with his past memories and is determined to start fresh with no regrets as Rudeus Greyrat, the child of two renowned adventurers.
#
# ...

# %%
#tokenization
text = corpus
sentence_list = nltk.sent_tokenize(text)
print(sentence_list)
# Out:
# ['Isekai is currently one of the most popular genres in anime which blew up after the massive success of Sword Art Online in 2012.', 'Despite not being the first of its kind, the popularity of SAO has spawned numerous isekai anime over the years, some with a similar setting having unique quirks while others being blatant clones of the previous.', 'With 21 isekai anime being released in 2021 alone, the genre definitely feels monotonous and overdone.', 'Mushoku Tensei, being one of them, may seem to be conceptually identical, but it could not be more different in terms of quality and execution.', "Adapted from Rifujin na Magonote's light novel, Mushoku Tensei builds on the concept of reincarnation in an alternate fantasy world, where the jobless and hopeless protagonist is reborn with his past memories and is determined to start fresh with no regrets as Rudeus Greyrat, the child of two renowned adventurers.", 'This setting may sound awfully familiar because it is.', 'Mushoku Tensei sta
# ...

# %%
# function to return a random greeting response
def greeting_res(text):
  text = text.lower()

  # Bots greeting res
  bot_greetings = ['howdy', 'hi', 'hey', 'hello', 'ni hao']
  #users greeting
  user_greetings = ['hi', 'hey', 'hello', 'hola', "what's up"]

  for word in text.split():
    if word in user_greetings:
      return random.choice(bot_greetings)

# %%
def index_sort(list_var):
  length = len(list_var)
  list_index = list(range(0, length))

  x = list_var

# %%
# create bots response
def bot_response(user_input):
  user_input = user_input.lower()
  sentence_list.append(user_input)
  bot_res = ''
  count_matrix = CountVectorizer().fit_transform(sentence_list)
  similarity_scores = cosine_similarity(count_matrix[-1], count_matrix)
  similarity_scores_list = similarity_scores.flatten()
  index = index_sort(similarity_scores)
